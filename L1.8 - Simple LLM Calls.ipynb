# %%
import openai
import os
client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))


from openai import OpenAI
client = OpenAI(
      base_url = "https://openai.vocareum.com/v1",
      api_key = os.getenv("OPENAI_API_KEY"),
)

# %%
model = "gpt-3.5-turbo"
temperature = 0.7

# %%
system_prompt = "Act as a B2B content creator, create marketing campaign text, to reach the audience of the company CultPass."

# %%
def create_content(query):
  messages = [
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": query}
  ]
  response = client.chat.completions.create(
      model=model,
      temperature=temperature,
      messages=messages
  )
  return response.choices[0].message.content

# %%
query = "Create an Instagram post for clients in the automotive industry."
result = create_content(query)
print(result)
# Out:
# 🚗 Calling all automotive professionals! 🚗
#
# Looking for a way to take your team's skills to the next level? Look no further! CultPass offers a wide range of training courses specifically designed for the automotive industry. From advanced vehicle diagnostics to cutting-edge technology integration, we've got you covered.
#
# Stay ahead of the competition and invest in your team's growth with CultPass. Get access to our library of online courses and resources to help your business thrive. Start your journey to success today!
#
# #AutomotiveIndustry #ProfessionalDevelopment #CultPass #TrainingCourses #StayAhead #SuccessJourney
